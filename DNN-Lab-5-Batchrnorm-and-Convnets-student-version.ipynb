# %% [markdown]
# <center><img src='https://drive.google.com/uc?id=1_utx_ZGclmCwNttSe40kYA6VHzNocdET' height="60"></center>
#
# AI TECH - Akademia Innowacyjnych Zastosowań Technologii Cyfrowych. Program Operacyjny Polska Cyfrowa na lata 2014-2020
# <hr>
#
# <center><img src='https://drive.google.com/uc?id=1BXZ0u3562N_MqCLcekI-Ens77Kk4LpPm'></center>
#
# <center>
# Projekt współfinansowany ze środków Unii Europejskiej w ramach Europejskiego Funduszu Rozwoju Regionalnego
# Program Operacyjny Polska Cyfrowa na lata 2014-2020,
# Oś Priorytetowa nr 3 "Cyfrowe kompetencje społeczeństwa" Działanie  nr 3.2 "Innowacyjne rozwiązania na rzecz aktywizacji cyfrowej"
# Tytuł projektu:  „Akademia Innowacyjnych Zastosowań Technologii Cyfrowych (AI Tech)”
#     </center>

# %% [markdown]
# Code based on https://github.com/pytorch/examples/blob/master/mnist/main.py
#
# This exercise covers two aspects:
# * In tasks 1-6 you will implement mechanisms that allow training deeper models (better initialization, batch normalization). Note that for dropout and batch norm you are expected to implement it yourself without relying on ready-made components from Pytorch. After doing each of the tasks you can look at the plots and check how your changes impact gradients of network layers.
# * In task 7 you will implement a convnet using [conv2d](https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html).
#
#
# Tasks:
# 1. Check that the given implementation reaches 95% test accuracy for
#    architecture input-64-64-10 in a few thousand batches.
# 2. Improve initialization and check that the network learns much faster
#    and reaches over 97% test accuracy. A good basic initialization scheme is so-called Glorot initialization. For a set of weights going from a layer with $n_{in}$ neurons to a layer with $n_{out}$ neurons, it samples each weight from normal distribution with $0$ mean and standard deviation of $\sqrt{\frac{2}{n_{in}+n_{out}}}$.
# Check how better initialization changes distribution of gradients at the first epoch.
# 3. Check, that with proper initialization we can train architecture
#    input-64-64-64-64-64-10, while with bad initialization it does
#    not even get off the ground.
# 4. Add dropout implemented in pytorch (but without using torch.nn.Dropout)
# 5. Check that with 10 hidden layers (64 units each) even with proper
#     initialization the network has a hard time to start learning.
# 6. Implement batch normalization (use train mode also for testing - it should perform well enough):
#     * compute batch mean and variance
#     * add new variables beta and gamma
#     * check that the networks learns much faster for 5 layers
#     * check that the network learns even for 10 hidden layers.
#     * check how gradients change in comparison to network without batch norm.
# 7. So far we worked with a fully connected network. Design and implement in pytorch (by using pytorch functions) a simple convolutional network and achieve 99% test accuracy. The architecture is up to you, but even a few convolutional layers should be enough.

# %%
import sys
import torch
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
import torch.optim as optim
from torch.nn.parameter import Parameter
from torch.nn import init
import torchvision
import torchvision.transforms as transforms
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

if 'google.colab' in sys.modules:
    from google.colab import output
    output.enable_custom_widget_manager()

# %%
# @title Visualize gradients

class GradientVisualizer:
    def __init__(self, net, num_epochs):
        self.num_epochs = num_epochs
        self.linear_layers = self.get_linear_layers(net)

        self.grad_to_weight_fig = None
        self.grads_in_layers_fig = None
        self.grads_at_epochs_fig = None
        self.init_figures()

    def get_linear_layers(self, net):
        linear_layers = []
        for field in net.__dict__['_modules'].values():
            if isinstance(field, Linear):
                linear_layers.append(field)
        return linear_layers

    def get_epochs_for_one_layer(self):
        """
        We want to show gradient distributions from up to 7 selected epochs
        for one linear layer.
        """
        if self.num_epochs < 7:
            return list(range(self.num_epochs))
        else:
            return torch.linspace(0, self.num_epochs - 1, 7).int().tolist()

    def get_three_epochs(self):
        """
        We want to show gradients distributions from all layers at each of
        three epochs: first, middle and last.
        """
        return [0, self.num_epochs // 2, self.num_epochs - 1]

    def rgb_to_rgba(self, rgb_color, epoch):
        """
        Value of epoch parameter determines how transparent color should be
        in comparison to others.
        Colors for earlier epochs should be more transparent/less visible.
        """
        return f'rgba{rgb_color[3:-1]},{0.6 * (epoch + 1) / self.num_epochs + 0.15})'

    def init_figures(self):
        # Initialize figure with gradient to weight ratio plot
        fig = go.Figure()
        fig.update_layout(
            title='Gradient standard deviation to weight standard deviation ratio', title_x=0.5,
            xaxis_title='Epoch',
            yaxis_title='Gradient to weight ratio (log scale)',
            height=400, width=1500, margin=dict(b=10, t=60)
        )
        fig.update_yaxes(type='log')
        for i in range(len(self.linear_layers)):
            fig.add_trace(go.Scatter(
                x=[], y=[],
                mode='lines+markers', name=f'Linear layer {i}'
            ))

        self.grad_to_weight_fig = go.FigureWidget(fig)
        display(self.grad_to_weight_fig)

        # Initialize figure visualizing gradient distributions in layers
        num_rows = (len(self.linear_layers) - 1) // 3 + 1
        fig = make_subplots(
            rows=num_rows, cols=3,
            subplot_titles=[f'Linear layer {i}' for i in range(len(self.linear_layers))]
        )
        fig.update_layout(
            title='Comparison between epochs of gradient distributions in layers', title_x=0.5,
            height=num_rows * 400, width=1500, margin=dict(b=10, t=60)
        )

        colors, _ = px.colors.convert_colors_to_same_type(px.colors.qualitative.Plotly)
        for layer_num in range(len(self.linear_layers)):
            row = layer_num // 3 + 1
            col = layer_num % 3 + 1
            fig.update_xaxes(
                title_text='Gradient value', range=(-0.1, 0.1), row=row, col=col
            )
            fig.update_yaxes(
                title_text='Density (log scale)', type='log', row=row, col=col
            )

            # Create empty traces and update them later with actual gradient distributions.
            # Unfortunately, we cannot add new traces dynamically because Colab has problem
            # with widgets from plotly (traces added dynamically are rendered twice).
            for epoch in self.get_epochs_for_one_layer():
                fig.add_trace(
                    go.Scatter(
                        mode='lines', name=f'Epoch {epoch + 1}',
                        line=dict(color=self.rgb_to_rgba(colors[layer_num], epoch)),
                        legendgroup=layer_num
                    ),
                    row=row, col=col
                )

        self.grads_in_layers_fig = go.FigureWidget(fig)
        display(self.grads_in_layers_fig)

        # Initialize figure comparing gradient distributions between layers at the
        # first, middle and last epoch
        selected_epochs_indices = self.get_three_epochs()
        fig = make_subplots(
            rows=1, cols=3,
            subplot_titles=[f'Epoch {epoch + 1}' for epoch in selected_epochs_indices]
        )
        fig.update_layout(
            title='Comparison between layers of gradient distributions at epochs', title_x=0.5,
            height=400, width=1500, margin=dict(b=10, t=60)
        )

        for col, epoch in enumerate(selected_epochs_indices, 1):
            fig.update_yaxes(title_text='Density (log scale)', type='log', row=1, col=col)
            fig.update_xaxes(
                title_text='Gradient value',
                range=(-0.05, 0.05) if epoch != 0 else (-1, 1),
                row=1, col=col
            )

            # Create empty traces and update them later with actual gradient distributions.
            for layer_num in range(len(self.linear_layers)):
                fig.append_trace(
                    go.Scatter(
                        mode='lines', name=f'Linear layer {layer_num}',
                        line=dict(color=colors[layer_num]), showlegend=(col == 1)
                    ),
                    row=1, col=col
                )

        self.grads_at_epochs_fig = go.FigureWidget(fig)
        display(self.grads_at_epochs_fig)

    def visualize_gradients(self, lr, epoch, batch_idx):
        # It is enough to use gradients calculated for the first batch.
        if batch_idx != 0:
            return

        epoch_grads = []
        epoch_grad_to_weight_ratios = []
        for layer in self.linear_layers:
            epoch_grads.append(layer.weight.grad.flatten().detach())
            epoch_grad_to_weight_ratios.append(
                (lr * layer.weight.grad.std() / layer.weight.std()).item()
            )

        # Update figure with gradient to weight ratio plot
        for i, grad_to_weight_ratio in enumerate(epoch_grad_to_weight_ratios):
            x = self.grad_to_weight_fig.data[i].x
            next_x_val = x[-1] + 1 if x else 1
            self.grad_to_weight_fig.data[i].x += (next_x_val, )
            self.grad_to_weight_fig.data[i].y += (grad_to_weight_ratio, )

        # Update figure visualizing gradient distributions in layers
        selected_epochs = self.get_epochs_for_one_layer()
        if epoch in selected_epochs:
            epoch_idx = selected_epochs.index(epoch)
            for layer_num, layer_grad in enumerate(epoch_grads):
                trace_idx = layer_num * len(selected_epochs) + epoch_idx
                hy, hx = torch.histogram(layer_grad, bins=50, density=True)
                hy = hy / max(hy) + 0.001
                self.grads_in_layers_fig.data[trace_idx].x = hx[:-1].tolist()
                self.grads_in_layers_fig.data[trace_idx].y = hy.tolist()

        # Update figure visualizing gradient distributions at epochs
        selected_epochs = self.get_three_epochs()
        if epoch in selected_epochs:
            epoch_idx = selected_epochs.index(epoch)
            for layer_num, layer_grad in enumerate(epoch_grads):
                trace_idx = epoch_idx * len(self.linear_layers) + layer_num
                hy, hx = torch.histogram(layer_grad, bins=50, density=True)
                hy = hy / max(hy) + 0.001
                self.grads_at_epochs_fig.data[trace_idx].x = hx[:-1].tolist()
                self.grads_at_epochs_fig.data[trace_idx].y = hy.tolist()

# %%
class Linear(torch.nn.Module):
    def __init__(self, in_features, out_features, dropout_prob = 0.0, use_batch_norm=True):
        super(Linear, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.weight = Parameter(torch.Tensor(out_features, in_features))
        self.bias = Parameter(torch.Tensor(out_features))
        self.dropout_prob = dropout_prob
        self.use_batch_norm = use_batch_norm
        self.reset_parameters()

        if use_batch_norm:
            self.gamma = Parameter(torch.Tensor(out_features))
            self.beta = Parameter(torch.Tensor(out_features))
            self.register_buffer('running_mean', torch.zeros(out_features))
            self.register_buffer('running_var', torch.ones(out_features))
            self.eps = 1e-8
            self.gamma.data.fill_(1)
            self.beta.data.zero_()


    def reset_parameters(self):
        stddev = np.sqrt(2 / (self.in_features + self.out_features))
        self.weight.data.normal_(mean=0,std=stddev)
        init.zeros_(self.bias)


    def forward(self, x):
        r = x.matmul(self.weight.t())
        r += self.bias
        if self.use_batch_norm:
            if self.training:
                mean = r.mean(dim=0)
                var = r.var(dim=0, correction=0)
                r = (r - mean) / torch.sqrt(var + self.eps)

                with torch.no_grad():
                    self.running_mean = 0.9 * self.running_mean + 0.1 * mean
                    self.running_var = 0.9 * self.running_var + 0.1 * var

            else:
                r = (r - self.running_mean) / torch.sqrt(self.running_var + self.eps)

            r = self.gamma * r + self.beta

        if self.training:
            r = self.dropout(r)

        return r

    def dropout(self, x):
        mask = (torch.rand(x.shape) > self.dropout_prob).float()
        x = x * mask / (1 - self.dropout_prob)
        return x


class Net(nn.Module):
    def __init__(self, use_batch_norm=True):
        super(Net, self).__init__()
        self.fc1 = Linear(784, 64, use_batch_norm=use_batch_norm)
        self.fc2 = Linear(64, 64, use_batch_norm=use_batch_norm)
        self.fc3 = Linear(64, 64, use_batch_norm=use_batch_norm)
        self.fc4 = Linear(64 ,64, use_batch_norm=use_batch_norm)
        self.fc5 = Linear(64, 64, use_batch_norm=use_batch_norm)
        self.fc6 = Linear(64, 64, use_batch_norm=use_batch_norm)
        self.fc7 = Linear(64, 64, use_batch_norm=use_batch_norm)
        self.fc8 = Linear(64, 64, use_batch_norm=use_batch_norm)
        self.fc9 = Linear(64, 64, use_batch_norm=use_batch_norm)
        self.fc10 = Linear(64, 10,use_batch_norm=False)

    def forward(self, x):
        x = x.view(-1, 28 * 28)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = F.relu(self.fc5(x))
        x = F.relu(self.fc6(x))
        x = F.relu(self.fc7(x))
        x = F.relu(self.fc8(x))
        x = F.relu(self.fc9(x))
        x = self.fc10(x)
        return x

# %%
class MnistTrainer(object):
    def __init__(self, batch_size):
        transform = transforms.Compose(
                [transforms.ToTensor()])
        self.trainset = torchvision.datasets.MNIST(
            root='./data',
            download=True,
            train=True,
            transform=transform)
        self.trainloader = torch.utils.data.DataLoader(
            self.trainset, batch_size=batch_size, shuffle=True, num_workers=2)

        self.testset = torchvision.datasets.MNIST(
            root='./data',
            train=False,
            download=True, transform=transform)
        self.testloader = torch.utils.data.DataLoader(
            self.testset, batch_size=1, shuffle=False, num_workers=2)

    def train(self, net, gradient_visualizer, epochs=20, lr=0.05, momentum=0.9):
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.SGD(net.parameters(), lr=lr, momentum=momentum)

        for epoch in range(epochs):
            running_loss = 0.0
            net.train()

            for i, data in enumerate(self.trainloader):
                inputs, labels = data
                optimizer.zero_grad()

                outputs = net(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                gradient_visualizer.visualize_gradients(lr, epoch, i)
                optimizer.step()

                running_loss += loss.item()
                if i % 100 == 99:
                    print('[%d, %5d] loss: %.3f' %
                          (epoch + 1, i + 1, running_loss / 100))
                    running_loss = 0.0

            net.eval()
            correct = 0
            total = 0
            with torch.no_grad():
                for data in self.testloader:
                    images, labels = data
                    outputs = net(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

            print('Accuracy of the network on the {} test images: {} %'.format(
                total, 100 * correct / total))

# %%
epochs = 20

net = Net()
gradient_visualizer = GradientVisualizer(net, epochs)
# Out:
# FigureWidget({
#     'data': [{'mode': 'lines+markers',
#               'name': 'Linear layer 0',
#               'type': 'scatter',
#               'uid': 'ec16cc01-b808-47e4-8d70-8fc54417f3c2',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'name': 'Linear layer 1',
#               'type': 'scatter',
#               'uid': '15634ca9-d2a5-4875-a7ce-430b7da93d81',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'name': 'Linear layer 2',
#               'type': 'scatter',
#               'uid': 'caa2290a-73ba-4591-b570-b4823306edab',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'name': 'Linear layer 3',
#               'type': 'scatter',
#               'uid': '415b6839-48c5-4307-b054-8e16999b81b1',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'name': 'Linear layer 4',
#               'type': 'scatter',
#               'uid': 'eea641c2-c828-4e64-993d-0337da74b5d1',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'name': 'Linear layer 5',
#               'type': 'scatter',
#               'uid': '362601d0-fa57-4ac6-8931-960901dfe3be',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'name': 'Linear layer 6',
#               'type': 'scatter',
#               'uid': '254f0654-6101-4c9c-a467-4e437e927745',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'name': 'Linear layer 7',
#               'type': 'scatter',
#               'uid': '5d6351c0-2bab-4c96-9483-57eb2249846b',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'name': 'Linear layer 8',
#               'type': 'scatter',
#               'uid': '266d0b9e-ef55-444d-8f16-2f3ae64d7c13',
#               'x': [],
#               'y': []},
#              {'mode': 'lines+markers',
#               'name': 'Linear layer 9',
#               'type': 'scatter',
#               'uid': '4ad5ac78-b8d1-488a-bc20-a44485d0a7bb',
#               'x': [],
#               'y': []}],
#     'layout': {'height': 400,
#                'margin': {'b': 10, 't': 60},
#                'template': '...',
#                'title': {'text': 'Gradient standard deviation to weight standard deviation ratio', 'x': 0.5},
#                'width': 1500,
#                'xaxis': {'title': {'text': 'Epoch'}},
#                'yaxis': {'title': {'text': 'Gradient to weight ratio (log scale)'}, 'type': 'log'}}
# })
# FigureWidget({
#     'data': [{'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.18)'},
#               'mode': 'lines',
#               'name': 'Epoch 1',
#               'type': 'scatter',
#               'uid': '814079ce-11f1-482d-a503-b2c76d88ee63',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.27)'},
#               'mode': 'lines',
#               'name': 'Epoch 4',
#               'type': 'scatter',
#               'uid': '9c57c1fa-8aa4-4869-838f-7879b1220f88',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.36)'},
#               'mode': 'lines',
#               'name': 'Epoch 7',
#               'type': 'scatter',
#               'uid': '03d4a66f-0ede-42b9-b5e8-7d3f7814df6a',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.44999999999999996)'},
#               'mode': 'lines',
#               'name': 'Epoch 10',
#               'type': 'scatter',
#               'uid': '062066e5-201f-4c49-8bbb-7e4244234f21',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.54)'},
#               'mode': 'lines',
#               'name': 'Epoch 13',
#               'type': 'scatter',
#               'uid': '4c1f880e-bc8e-4bb9-95a0-16d9f1669538',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.63)'},
#               'mode': 'lines',
#               'name': 'Epoch 16',
#               'type': 'scatter',
#               'uid': '1ef8c85a-7a5f-433b-9908-4678e6b23880',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': 'rgba(99, 110, 250,0.75)'},
#               'mode': 'lines',
#               'name': 'Epoch 20',
#               'type': 'scatter',
#               'uid': '4b840622-08d8-4e76-a8e3-30d2e40885de',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'legendgroup': '1',
#               'line': {'color': 'rgba(239, 85, 59,0.18)'},
#               'mode': 'lines',
#               'name': 'Epoch 1',
#               'type': 'scatter',
#               'uid': '21db3392-4bce-49f0-bc7e-1da47d5f98c5',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '1',
#               'line': {'color': 'rgba(239, 85, 59,0.27)'},
#               'mode': 'lines',
#               'name': 'Epoch 4',
#               'type': 'scatter',
#               'uid': '7a8ce3f3-377a-4a7d-9321-c9875c055012',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '1',
#               'line': {'color': 'rgba(239, 85, 59,0.36)'},
#               'mode': 'lines',
#               'name': 'Epoch 7',
#               'type': 'scatter',
#               'uid': 'ff1ef763-0883-43e2-a2fc-892d92003c35',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '1',
#               'line': {'color': 'rgba(239, 85, 59,0.44999999999999996)'},
#               'mode': 'lines',
#               'name': 'Epoch 10',
#               'type': 'scatter',
#               'uid': 'ebde7dd2-13fa-4c24-8a87-e9e640177e4b',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '1',
#               'line': {'color': 'rgba(239, 85, 59,0.54)'},
#               'mode': 'lines',
#               'name': 'Epoch 13',
#               'type': 'scatter',
#               'uid': 'fc5a0f01-bd70-472c-91de-c2e8048360e3',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '1',
#               'line': {'color': 'rgba(239, 85, 59,0.63)'},
#               'mode': 'lines',
#               'name': 'Epoch 16',
#               'type': 'scatter',
#               'uid': '0341be89-4f2d-4d0e-9ca2-1a5d1869b2a1',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '1',
#               'line': {'color': 'rgba(239, 85, 59,0.75)'},
#               'mode': 'lines',
#               'name': 'Epoch 20',
#               'type': 'scatter',
#               'uid': 'b4cf803b-b72c-4fd3-8583-5ca3f0d83bce',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'legendgroup': '2',
#               'line': {'color': 'rgba(0, 204, 150,0.18)'},
#               'mode': 'lines',
#               'name': 'Epoch 1',
#               'type': 'scatter',
#               'uid': 'e4d0b117-bc42-4b5e-b86c-6dea8a49b221',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'legendgroup': '2',
#               'line': {'color': 'rgba(0, 204, 150,0.27)'},
#               'mode': 'lines',
#               'name': 'Epoch 4',
#               'type': 'scatter',
#               'uid': '3fa94f49-c6fe-4b9a-acb8-8fca5fc4bfd9',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'legendgroup': '2',
#               'line': {'color': 'rgba(0, 204, 150,0.36)'},
#               'mode': 'lines',
#               'name': 'Epoch 7',
#               'type': 'scatter',
#               'uid': '671d090d-b1d9-4ed1-b49d-89a8d8ed179f',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'legendgroup': '2',
#               'line': {'color': 'rgba(0, 204, 150,0.44999999999999996)'},
#               'mode': 'lines',
#               'name': 'Epoch 10',
#               'type': 'scatter',
#               'uid': '3a41728c-9ab1-425f-9fd0-81d6c91efb4c',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'legendgroup': '2',
#               'line': {'color': 'rgba(0, 204, 150,0.54)'},
#               'mode': 'lines',
#               'name': 'Epoch 13',
#               'type': 'scatter',
#               'uid': '187e18f5-2863-4dbf-82f0-0218375e3b04',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'legendgroup': '2',
#               'line': {'color': 'rgba(0, 204, 150,0.63)'},
#               'mode': 'lines',
#               'name': 'Epoch 16',
#               'type': 'scatter',
#               'uid': 'a5dcb952-4291-457f-ad12-9caaea4db88c',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'legendgroup': '2',
#               'line': {'color': 'rgba(0, 204, 150,0.75)'},
#               'mode': 'lines',
#               'name': 'Epoch 20',
#               'type': 'scatter',
#               'uid': '69d7d3b7-d3a7-49c5-852f-6435fb9f7813',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'legendgroup': '3',
#               'line': {'color': 'rgba(171, 99, 250,0.18)'},
#               'mode': 'lines',
#               'name': 'Epoch 1',
#               'type': 'scatter',
#               'uid': '22d26bc2-ddcb-4063-b2aa-b86ba16f29fd',
#               'xaxis': 'x4',
#               'yaxis': 'y4'},
#              {'legendgroup': '3',
#               'line': {'color': 'rgba(171, 99, 250,0.27)'},
#               'mode': 'lines',
#               'name': 'Epoch 4',
#               'type': 'scatter',
#               'uid': '11ecfadb-5f8f-4141-934d-6145fad50681',
#               'xaxis': 'x4',
#               'yaxis': 'y4'},
#              {'legendgroup': '3',
#               'line': {'color': 'rgba(171, 99, 250,0.36)'},
#               'mode': 'lines',
#               'name': 'Epoch 7',
#               'type': 'scatter',
#               'uid': 'bd1667df-a67b-4be4-aab3-24e0f9275c4c',
#               'xaxis': 'x4',
#               'yaxis': 'y4'},
#              {'legendgroup': '3',
#               'line': {'color': 'rgba(171, 99, 250,0.44999999999999996)'},
#               'mode': 'lines',
#               'name': 'Epoch 10',
#               'type': 'scatter',
#               'uid': '4223edd6-3f40-4087-a36a-a56b3fe5be24',
#               'xaxis': 'x4',
#               'yaxis': 'y4'},
#              {'legendgroup': '3',
#               'line': {'color': 'rgba(171, 99, 250,0.54)'},
#               'mode': 'lines',
#               'name': 'Epoch 13',
#               'type': 'scatter',
#               'uid': 'a162e4fa-a438-4a6a-ada8-9bccabff1cc3',
#               'xaxis': 'x4',
#               'yaxis': 'y4'},
#              {'legendgroup': '3',
#               'line': {'color': 'rgba(171, 99, 250,0.63)'},
#               'mode': 'lines',
#               'name': 'Epoch 16',
#               'type': 'scatter',
#               'uid': '35e25c1f-6a67-4ad8-ae02-285b8c788263',
#               'xaxis': 'x4',
#               'yaxis': 'y4'},
#              {'legendgroup': '3',
#               'line': {'color': 'rgba(171, 99, 250,0.75)'},
#               'mode': 'lines',
#               'name': 'Epoch 20',
#               'type': 'scatter',
#               'uid': 'a78087f3-b0db-4e85-af9f-63998fab6fa5',
#               'xaxis': 'x4',
#               'yaxis': 'y4'},
#              {'legendgroup': '4',
#               'line': {'color': 'rgba(255, 161, 90,0.18)'},
#               'mode': 'lines',
#               'name': 'Epoch 1',
#               'type': 'scatter',
#               'uid': 'b272db88-624d-4caa-bd17-f3fc1b1eea8c',
#               'xaxis': 'x5',
#               'yaxis': 'y5'},
#              {'legendgroup': '4',
#               'line': {'color': 'rgba(255, 161, 90,0.27)'},
#               'mode': 'lines',
#               'name': 'Epoch 4',
#               'type': 'scatter',
#               'uid': 'c1dac3d7-d2e2-45bd-9d64-2a670db73cac',
#               'xaxis': 'x5',
#               'yaxis': 'y5'},
#              {'legendgroup': '4',
#               'line': {'color': 'rgba(255, 161, 90,0.36)'},
#               'mode': 'lines',
#               'name': 'Epoch 7',
#               'type': 'scatter',
#               'uid': '070aa614-fbb0-4158-b41b-cff604fec4b1',
#               'xaxis': 'x5',
#               'yaxis': 'y5'},
#              {'legendgroup': '4',
#               'line': {'color': 'rgba(255, 161, 90,0.44999999999999996)'},
#               'mode': 'lines',
#               'name': 'Epoch 10',
#               'type': 'scatter',
#               'uid': '2989c09c-2cbf-4f1d-8355-74e9bf853cea',
#               'xaxis': 'x5',
#               'yaxis': 'y5'},
#              {'legendgroup': '4',
#               'line': {'color': 'rgba(255, 161, 90,0.54)'},
#               'mode': 'lines',
#               'name': 'Epoch 13',
#               'type': 'scatter',
#               'uid': '663c84f0-6681-457b-a6bb-4d7327c61951',
#               'xaxis': 'x5',
#               'yaxis': 'y5'},
#              {'legendgroup': '4',
#               'line': {'color': 'rgba(255, 161, 90,0.63)'},
#               'mode': 'lines',
#               'name': 'Epoch 16',
#               'type': 'scatter',
#               'uid': 'f8e16994-640d-47bb-a92a-d03dc86515a7',
#               'xaxis': 'x5',
#               'yaxis': 'y5'},
#              {'legendgroup': '4',
#               'line': {'color': 'rgba(255, 161, 90,0.75)'},
#               'mode': 'lines',
#               'name': 'Epoch 20',
#               'type': 'scatter',
#               'uid': 'deeab624-767c-4158-a9fe-07fb92e1c849',
#               'xaxis': 'x5',
#               'yaxis': 'y5'},
#              {'legendgroup': '5',
#               'line': {'color': 'rgba(25, 211, 243,0.18)'},
#               'mode': 'lines',
#               'name': 'Epoch 1',
#               'type': 'scatter',
#               'uid': 'cb612de1-d32b-4d12-a4aa-c31a7b58b7dc',
#               'xaxis': 'x6',
#               'yaxis': 'y6'},
#              {'legendgroup': '5',
#               'line': {'color': 'rgba(25, 211, 243,0.27)'},
#               'mode': 'lines',
#               'name': 'Epoch 4',
#               'type': 'scatter',
#               'uid': '2d103115-18a6-4284-bf62-868f4e11fcda',
#               'xaxis': 'x6',
#               'yaxis': 'y6'},
#              {'legendgroup': '5',
#               'line': {'color': 'rgba(25, 211, 243,0.36)'},
#               'mode': 'lines',
#               'name': 'Epoch 7',
#               'type': 'scatter',
#               'uid': '4badfbfb-7994-4f7c-a97c-0a4b7a0070e9',
#               'xaxis': 'x6',
#               'yaxis': 'y6'},
#              {'legendgroup': '5',
#               'line': {'color': 'rgba(25, 211, 243,0.44999999999999996)'},
#               'mode': 'lines',
#               'name': 'Epoch 10',
#               'type': 'scatter',
#               'uid': 'aed9e1c2-47d1-4f0c-95c7-7b04d5ab4894',
#               'xaxis': 'x6',
#               'yaxis': 'y6'},
#              {'legendgroup': '5',
#               'line': {'color': 'rgba(25, 211, 243,0.54)'},
#               'mode': 'lines',
#               'name': 'Epoch 13',
#               'type': 'scatter',
#               'uid': '0cefa261-267f-4b31-82c2-c4f7d68af2e4',
#               'xaxis': 'x6',
#               'yaxis': 'y6'},
#              {'legendgroup': '5',
#               'line': {'color': 'rgba(25, 211, 243,0.63)'},
#               'mode': 'lines',
#               'name': 'Epoch 16',
#               'type': 'scatter',
#               'uid': 'd3cf32a4-e048-461e-8497-bb2a202f4cd1',
#               'xaxis': 'x6',
#               'yaxis': 'y6'},
#              {'legendgroup': '5',
#               'line': {'color': 'rgba(25, 211, 243,0.75)'},
#               'mode': 'lines',
#               'name': 'Epoch 20',
#               'type': 'scatter',
#               'uid': '5cb01dbf-1761-49fb-9e40-d927a12aa648',
#               'xaxis': 'x6',
#               'yaxis': 'y6'},
#              {'legendgroup': '6',
#               'line': {'color': 'rgba(255, 102, 146,0.18)'},
#               'mode': 'lines',
#               'name': 'Epoch 1',
#               'type': 'scatter',
#               'uid': '2025985c-0031-45c1-a41b-c45905cf355b',
#               'xaxis': 'x7',
#               'yaxis': 'y7'},
#              {'legendgroup': '6',
#               'line': {'color': 'rgba(255, 102, 146,0.27)'},
#               'mode': 'lines',
#               'name': 'Epoch 4',
#               'type': 'scatter',
#               'uid': 'e45073b1-1072-4f39-81ba-f7f600a82c33',
#               'xaxis': 'x7',
#               'yaxis': 'y7'},
#              {'legendgroup': '6',
#               'line': {'color': 'rgba(255, 102, 146,0.36)'},
#               'mode': 'lines',
#               'name': 'Epoch 7',
#               'type': 'scatter',
#               'uid': '3b4d0564-20f2-4c5e-8079-6b4ef2d0bbf6',
#               'xaxis': 'x7',
#               'yaxis': 'y7'},
#              {'legendgroup': '6',
#               'line': {'color': 'rgba(255, 102, 146,0.44999999999999996)'},
#               'mode': 'lines',
#               'name': 'Epoch 10',
#               'type': 'scatter',
#               'uid': '18b4f750-18ca-484e-accb-7ac8cffd892f',
#               'xaxis': 'x7',
#               'yaxis': 'y7'},
#              {'legendgroup': '6',
#               'line': {'color': 'rgba(255, 102, 146,0.54)'},
#               'mode': 'lines',
#               'name': 'Epoch 13',
#               'type': 'scatter',
#               'uid': '005413fe-9bbc-49ac-baa4-acbfac66915f',
#               'xaxis': 'x7',
#               'yaxis': 'y7'},
#              {'legendgroup': '6',
#               'line': {'color': 'rgba(255, 102, 146,0.63)'},
#               'mode': 'lines',
#               'name': 'Epoch 16',
#               'type': 'scatter',
#               'uid': 'a04ca2be-2106-4c44-8459-69efe9108972',
#               'xaxis': 'x7',
#               'yaxis': 'y7'},
#              {'legendgroup': '6',
#               'line': {'color': 'rgba(255, 102, 146,0.75)'},
#               'mode': 'lines',
#               'name': 'Epoch 20',
#               'type': 'scatter',
#               'uid': '8df8f4b7-cc06-47a7-9e26-d20b3371ebd5',
#               'xaxis': 'x7',
#               'yaxis': 'y7'},
#              {'legendgroup': '7',
#               'line': {'color': 'rgba(182, 232, 128,0.18)'},
#               'mode': 'lines',
#               'name': 'Epoch 1',
#               'type': 'scatter',
#               'uid': '95addbf8-8106-4440-b2f0-3d0aaf683564',
#               'xaxis': 'x8',
#               'yaxis': 'y8'},
#              {'legendgroup': '7',
#               'line': {'color': 'rgba(182, 232, 128,0.27)'},
#               'mode': 'lines',
#               'name': 'Epoch 4',
#               'type': 'scatter',
#               'uid': '0c035ae1-05d0-412e-a8af-fa9552002b97',
#               'xaxis': 'x8',
#               'yaxis': 'y8'},
#              {'legendgroup': '7',
#               'line': {'color': 'rgba(182, 232, 128,0.36)'},
#               'mode': 'lines',
#               'name': 'Epoch 7',
#               'type': 'scatter',
#               'uid': '0dda00bb-da6e-478e-9363-5cfcd74c9acd',
#               'xaxis': 'x8',
#               'yaxis': 'y8'},
#              {'legendgroup': '7',
#               'line': {'color': 'rgba(182, 232, 128,0.44999999999999996)'},
#               'mode': 'lines',
#               'name': 'Epoch 10',
#               'type': 'scatter',
#               'uid': '248c8f10-5950-459d-bac5-45e4f52f759e',
#               'xaxis': 'x8',
#               'yaxis': 'y8'},
#              {'legendgroup': '7',
#               'line': {'color': 'rgba(182, 232, 128,0.54)'},
#               'mode': 'lines',
#               'name': 'Epoch 13',
#               'type': 'scatter',
#               'uid': 'a87c7115-eb06-43d5-bea0-eba18c949b6b',
#               'xaxis': 'x8',
#               'yaxis': 'y8'},
#              {'legendgroup': '7',
#               'line': {'color': 'rgba(182, 232, 128,0.63)'},
#               'mode': 'lines',
#               'name': 'Epoch 16',
#               'type': 'scatter',
#               'uid': 'eca3a3c1-1045-462b-a109-1ebb72449a8e',
#               'xaxis': 'x8',
#               'yaxis': 'y8'},
#              {'legendgroup': '7',
#               'line': {'color': 'rgba(182, 232, 128,0.75)'},
#               'mode': 'lines',
#               'name': 'Epoch 20',
#               'type': 'scatter',
#               'uid': 'ceaafbd6-037f-4e06-b1e6-0fc01dd00e54',
#               'xaxis': 'x8',
#               'yaxis': 'y8'},
#              {'legendgroup': '8',
#               'line': {'color': 'rgba(255, 151, 255,0.18)'},
#               'mode': 'lines',
#               'name': 'Epoch 1',
#               'type': 'scatter',
#               'uid': 'd2d511a0-5855-469a-aea6-9613d30a31a5',
#               'xaxis': 'x9',
#               'yaxis': 'y9'},
#              {'legendgroup': '8',
#               'line': {'color': 'rgba(255, 151, 255,0.27)'},
#               'mode': 'lines',
#               'name': 'Epoch 4',
#               'type': 'scatter',
#               'uid': 'ca95a6c7-baec-4388-92d5-adc4de903915',
#               'xaxis': 'x9',
#               'yaxis': 'y9'},
#              {'legendgroup': '8',
#               'line': {'color': 'rgba(255, 151, 255,0.36)'},
#               'mode': 'lines',
#               'name': 'Epoch 7',
#               'type': 'scatter',
#               'uid': '4a1545e3-5c68-4013-9891-eb459410777c',
#               'xaxis': 'x9',
#               'yaxis': 'y9'},
#              {'legendgroup': '8',
#               'line': {'color': 'rgba(255, 151, 255,0.44999999999999996)'},
#               'mode': 'lines',
#               'name': 'Epoch 10',
#               'type': 'scatter',
#               'uid': '93be7831-4ad1-401e-b2f3-3851617904a2',
#               'xaxis': 'x9',
#               'yaxis': 'y9'},
#              {'legendgroup': '8',
#               'line': {'color': 'rgba(255, 151, 255,0.54)'},
#               'mode': 'lines',
#               'name': 'Epoch 13',
#               'type': 'scatter',
#               'uid': '36d523ce-04a4-44d3-8830-d1129ecbd6ea',
#               'xaxis': 'x9',
#               'yaxis': 'y9'},
#              {'legendgroup': '8',
#               'line': {'color': 'rgba(255, 151, 255,0.63)'},
#               'mode': 'lines',
#               'name': 'Epoch 16',
#               'type': 'scatter',
#               'uid': '8ff60c81-a5c1-4c88-b8b1-f001f0b9376c',
#               'xaxis': 'x9',
#               'yaxis': 'y9'},
#              {'legendgroup': '8',
#               'line': {'color': 'rgba(255, 151, 255,0.75)'},
#               'mode': 'lines',
#               'name': 'Epoch 20',
#               'type': 'scatter',
#               'uid': '505ff96d-41d6-4838-ad06-0fe46b92f018',
#               'xaxis': 'x9',
#               'yaxis': 'y9'},
#              {'legendgroup': '9',
#               'line': {'color': 'rgba(254, 203, 82,0.18)'},
#               'mode': 'lines',
#               'name': 'Epoch 1',
#               'type': 'scatter',
#               'uid': '269e7449-b158-4e7d-a75c-55fb65b9a2f6',
#               'xaxis': 'x10',
#               'yaxis': 'y10'},
#              {'legendgroup': '9',
#               'line': {'color': 'rgba(254, 203, 82,0.27)'},
#               'mode': 'lines',
#               'name': 'Epoch 4',
#               'type': 'scatter',
#               'uid': 'f1c0c5c0-5aea-4831-b681-d568e6562f3b',
#               'xaxis': 'x10',
#               'yaxis': 'y10'},
#              {'legendgroup': '9',
#               'line': {'color': 'rgba(254, 203, 82,0.36)'},
#               'mode': 'lines',
#               'name': 'Epoch 7',
#               'type': 'scatter',
#               'uid': '24d5549e-58ba-4aa4-b14f-26dc401f4270',
#               'xaxis': 'x10',
#               'yaxis': 'y10'},
#              {'legendgroup': '9',
#               'line': {'color': 'rgba(254, 203, 82,0.44999999999999996)'},
#               'mode': 'lines',
#               'name': 'Epoch 10',
#               'type': 'scatter',
#               'uid': '58846710-6f34-48ff-8197-e9d71a8f5367',
#               'xaxis': 'x10',
#               'yaxis': 'y10'},
#              {'legendgroup': '9',
#               'line': {'color': 'rgba(254, 203, 82,0.54)'},
#               'mode': 'lines',
#               'name': 'Epoch 13',
#               'type': 'scatter',
#               'uid': '89cd5014-2940-44f8-bbf9-a7797b19738c',
#               'xaxis': 'x10',
#               'yaxis': 'y10'},
#              {'legendgroup': '9',
#               'line': {'color': 'rgba(254, 203, 82,0.63)'},
#               'mode': 'lines',
#               'name': 'Epoch 16',
#               'type': 'scatter',
#               'uid': 'eb547f75-b6ba-44e3-a870-081d5ec86c3b',
#               'xaxis': 'x10',
#               'yaxis': 'y10'},
#              {'legendgroup': '9',
#               'line': {'color': 'rgba(254, 203, 82,0.75)'},
#               'mode': 'lines',
#               'name': 'Epoch 20',
#               'type': 'scatter',
#               'uid': '3fb8e742-29f8-47dd-84d1-4d222c8e1579',
#               'xaxis': 'x10',
#               'yaxis': 'y10'}],
#     'layout': {'annotations': [{'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Linear layer 0',
#                                 'x': 0.14444444444444446,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Linear layer 1',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Linear layer 2',
#                                 'x': 0.8555555555555556,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Linear layer 3',
#                                 'x': 0.14444444444444446,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.71875,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Linear layer 4',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.71875,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Linear layer 5',
#                                 'x': 0.8555555555555556,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.71875,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Linear layer 6',
#                                 'x': 0.14444444444444446,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.4375,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Linear layer 7',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.4375,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Linear layer 8',
#                                 'x': 0.8555555555555556,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.4375,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Linear layer 9',
#                                 'x': 0.14444444444444446,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.15625,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'height': 1600,
#                'margin': {'b': 10, 't': 60},
#                'template': '...',
#                'title': {'text': 'Comparison between epochs of gradient distributions in layers', 'x': 0.5},
#                'width': 1500,
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 0.2888888888888889],
#                          'range': [-0.1, 0.1],
#                          'title': {'text': 'Gradient value'}},
#                'xaxis10': {'anchor': 'y10',
#                            'domain': [0.0, 0.2888888888888889],
#                            'range': [-0.1, 0.1],
#                            'title': {'text': 'Gradient value'}},
#                'xaxis11': {'anchor': 'y11', 'domain': [0.35555555555555557, 0.6444444444444445]},
#                'xaxis12': {'anchor': 'y12', 'domain': [0.7111111111111111, 1.0]},
#                'xaxis2': {'anchor': 'y2',
#                           'domain': [0.35555555555555557, 0.6444444444444445],
#                           'range': [-0.1, 0.1],
#                           'title': {'text': 'Gradient value'}},
#                'xaxis3': {'anchor': 'y3',
#                           'domain': [0.7111111111111111, 1.0],
#                           'range': [-0.1, 0.1],
#                           'title': {'text': 'Gradient value'}},
#                'xaxis4': {'anchor': 'y4',
#                           'domain': [0.0, 0.2888888888888889],
#                           'range': [-0.1, 0.1],
#                           'title': {'text': 'Gradient value'}},
#                'xaxis5': {'anchor': 'y5',
#                           'domain': [0.35555555555555557, 0.6444444444444445],
#                           'range': [-0.1, 0.1],
#                           'title': {'text': 'Gradient value'}},
#                'xaxis6': {'anchor': 'y6',
#                           'domain': [0.7111111111111111, 1.0],
#                           'range': [-0.1, 0.1],
#                           'title': {'text': 'Gradient value'}},
#                'xaxis7': {'anchor': 'y7',
#                           'domain': [0.0, 0.2888888888888889],
#                           'range': [-0.1, 0.1],
#                           'title': {'text': 'Gradient value'}},
#                'xaxis8': {'anchor': 'y8',
#                           'domain': [0.35555555555555557, 0.6444444444444445],
#                           'range': [-0.1, 0.1],
#                           'title': {'text': 'Gradient value'}},
#                'xaxis9': {'anchor': 'y9',
#                           'domain': [0.7111111111111111, 1.0],
#                           'range': [-0.1, 0.1],
#                           'title': {'text': 'Gradient value'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.84375, 1.0], 'title': {'text': 'Density (log scale)'}, 'type': 'log'},
#                'yaxis10': {'anchor': 'x10',
#                            'domain': [0.0, 0.15625],
#                            'title': {'text': 'Density (log scale)'},
#                            'type': 'log'},
#                'yaxis11': {'anchor': 'x11', 'domain': [0.0, 0.15625]},
#                'yaxis12': {'anchor': 'x12', 'domain': [0.0, 0.15625]},
#                'yaxis2': {'anchor': 'x2',
#                           'domain': [0.84375, 1.0],
#                           'title': {'text': 'Density (log scale)'},
#                           'type': 'log'},
#                'yaxis3': {'anchor': 'x3',
#                           'domain': [0.84375, 1.0],
#                           'title': {'text': 'Density (log scale)'},
#                           'type': 'log'},
#                'yaxis4': {'anchor': 'x4',
#                           'domain': [0.5625, 0.71875],
#                           'title': {'text': 'Density (log scale)'},
#                           'type': 'log'},
#                'yaxis5': {'anchor': 'x5',
#                           'domain': [0.5625, 0.71875],
#                           'title': {'text': 'Density (log scale)'},
#                           'type': 'log'},
#                'yaxis6': {'anchor': 'x6',
#                           'domain': [0.5625, 0.71875],
#                           'title': {'text': 'Density (log scale)'},
#                           'type': 'log'},
#                'yaxis7': {'anchor': 'x7',
#                           'domain': [0.28125, 0.4375],
#                           'title': {'text': 'Density (log scale)'},
#                           'type': 'log'},
#                'yaxis8': {'anchor': 'x8',
#                           'domain': [0.28125, 0.4375],
#                           'title': {'text': 'Density (log scale)'},
#                           'type': 'log'},
#                'yaxis9': {'anchor': 'x9',
#                           'domain': [0.28125, 0.4375],
#                           'title': {'text': 'Density (log scale)'},
#                           'type': 'log'}}
# })
# FigureWidget({
#     'data': [{'line': {'color': 'rgb(99, 110, 250)'},
#               'mode': 'lines',
#               'name': 'Linear layer 0',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'b8447c3b-6742-47c8-88bf-1a62c8b90e16',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'rgb(239, 85, 59)'},
#               'mode': 'lines',
#               'name': 'Linear layer 1',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '5069f829-5c19-48a2-8e64-bd64b7bfd96d',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'rgb(0, 204, 150)'},
#               'mode': 'lines',
#               'name': 'Linear layer 2',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'ce916a1d-ef75-46a3-989d-60656bf3fdfd',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'rgb(171, 99, 250)'},
#               'mode': 'lines',
#               'name': 'Linear layer 3',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'e5cead0c-6cf0-45eb-a876-a5614375f019',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'rgb(255, 161, 90)'},
#               'mode': 'lines',
#               'name': 'Linear layer 4',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'f738a7e7-d48a-4785-a948-fde05f52c324',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'rgb(25, 211, 243)'},
#               'mode': 'lines',
#               'name': 'Linear layer 5',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '7954d784-fa9a-484b-b8ef-2afedc79bee3',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'rgb(255, 102, 146)'},
#               'mode': 'lines',
#               'name': 'Linear layer 6',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'c913bc58-fef4-49a3-b9c2-f5aa1ef0c604',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'rgb(182, 232, 128)'},
#               'mode': 'lines',
#               'name': 'Linear layer 7',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'a603a841-75dd-4b7d-acfb-b4eef67abeb3',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'rgb(255, 151, 255)'},
#               'mode': 'lines',
#               'name': 'Linear layer 8',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '78dac6c5-157f-4b41-b5dd-7b1656bd64ec',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'rgb(254, 203, 82)'},
#               'mode': 'lines',
#               'name': 'Linear layer 9',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'b9f90b0d-c2f1-48d5-aaf8-3cafbace8313',
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'line': {'color': 'rgb(99, 110, 250)'},
#               'mode': 'lines',
#               'name': 'Linear layer 0',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'c370cb79-99df-4920-bda8-e8027807fac3',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': 'rgb(239, 85, 59)'},
#               'mode': 'lines',
#               'name': 'Linear layer 1',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'c53e58a4-184b-47fa-9df1-f789a9167bc2',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': 'rgb(0, 204, 150)'},
#               'mode': 'lines',
#               'name': 'Linear layer 2',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'c8215e5c-5993-4e1c-a8cc-e377a7744fbb',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': 'rgb(171, 99, 250)'},
#               'mode': 'lines',
#               'name': 'Linear layer 3',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'f8ea7fbe-cf68-4f66-be12-dff3e9629a59',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': 'rgb(255, 161, 90)'},
#               'mode': 'lines',
#               'name': 'Linear layer 4',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'd15fbcfe-a7a9-457d-94c2-98b78f2d91e2',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': 'rgb(25, 211, 243)'},
#               'mode': 'lines',
#               'name': 'Linear layer 5',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '65fcaeb6-2dc2-473c-8748-691725eb536d',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': 'rgb(255, 102, 146)'},
#               'mode': 'lines',
#               'name': 'Linear layer 6',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '25d81639-adb8-47fa-bd89-f7aa9513abf5',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': 'rgb(182, 232, 128)'},
#               'mode': 'lines',
#               'name': 'Linear layer 7',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0c69a290-24c6-44d0-948e-9e690f809444',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': 'rgb(255, 151, 255)'},
#               'mode': 'lines',
#               'name': 'Linear layer 8',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0785ee7f-c100-44b5-8087-d99ca671aa95',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': 'rgb(254, 203, 82)'},
#               'mode': 'lines',
#               'name': 'Linear layer 9',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '9a206282-19ec-423f-a876-6ebb5aac4f54',
#               'xaxis': 'x2',
#               'yaxis': 'y2'},
#              {'line': {'color': 'rgb(99, 110, 250)'},
#               'mode': 'lines',
#               'name': 'Linear layer 0',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'e7be2e61-b983-4293-bea9-a1d817f81ba9',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'line': {'color': 'rgb(239, 85, 59)'},
#               'mode': 'lines',
#               'name': 'Linear layer 1',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '50a823b3-90fc-4b34-bc6b-1867cdacbc22',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'line': {'color': 'rgb(0, 204, 150)'},
#               'mode': 'lines',
#               'name': 'Linear layer 2',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'ed48347b-0bad-4fa7-8f7b-496761d4d955',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'line': {'color': 'rgb(171, 99, 250)'},
#               'mode': 'lines',
#               'name': 'Linear layer 3',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '4d10e6a3-a79f-4d85-82e8-121b3f25e522',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'line': {'color': 'rgb(255, 161, 90)'},
#               'mode': 'lines',
#               'name': 'Linear layer 4',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'a3ccebaf-f88e-440c-84f2-e5fdd029e1a5',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'line': {'color': 'rgb(25, 211, 243)'},
#               'mode': 'lines',
#               'name': 'Linear layer 5',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'e2522209-be7e-4cea-851e-46e8d5dd0ee4',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'line': {'color': 'rgb(255, 102, 146)'},
#               'mode': 'lines',
#               'name': 'Linear layer 6',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '6cbc9354-c861-46dd-98dd-38e4f8dbce71',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'line': {'color': 'rgb(182, 232, 128)'},
#               'mode': 'lines',
#               'name': 'Linear layer 7',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'd84b5964-4cd5-42ed-bf39-49a1dab0f266',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'line': {'color': 'rgb(255, 151, 255)'},
#               'mode': 'lines',
#               'name': 'Linear layer 8',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '01896566-c84b-4391-947b-16eff76354b5',
#               'xaxis': 'x3',
#               'yaxis': 'y3'},
#              {'line': {'color': 'rgb(254, 203, 82)'},
#               'mode': 'lines',
#               'name': 'Linear layer 9',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '01f6c47f-b60b-4873-936f-4804bb2567a7',
#               'xaxis': 'x3',
#               'yaxis': 'y3'}],
#     'layout': {'annotations': [{'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Epoch 1',
#                                 'x': 0.14444444444444446,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Epoch 11',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Epoch 20',
#                                 'x': 0.8555555555555556,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'height': 400,
#                'margin': {'b': 10, 't': 60},
#                'template': '...',
#                'title': {'text': 'Comparison between layers of gradient distributions at epochs', 'x': 0.5},
#                'width': 1500,
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 0.2888888888888889],
#                          'range': [-1, 1],
#                          'title': {'text': 'Gradient value'}},
#                'xaxis2': {'anchor': 'y2',
#                           'domain': [0.35555555555555557, 0.6444444444444445],
#                           'range': [-0.05, 0.05],
#                           'title': {'text': 'Gradient value'}},
#                'xaxis3': {'anchor': 'y3',
#                           'domain': [0.7111111111111111, 1.0],
#                           'range': [-0.05, 0.05],
#                           'title': {'text': 'Gradient value'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'Density (log scale)'}, 'type': 'log'},
#                'yaxis2': {'anchor': 'x2', 'domain': [0.0, 1.0], 'title': {'text': 'Density (log scale)'}, 'type': 'log'},
#                'yaxis3': {'anchor': 'x3', 'domain': [0.0, 1.0], 'title': {'text': 'Density (log scale)'}, 'type': 'log'}}
# })

# %%
trainer = MnistTrainer(batch_size=128)
trainer.train(net, gradient_visualizer, epochs=epochs)
# Out:
# [1,   100] loss: 0.742
# [1,   200] loss: 0.289
# [1,   300] loss: 0.265
# [1,   400] loss: 0.219
# Accuracy of the network on the 10000 test images: 95.2 %
# [2,   100] loss: 0.169
# [2,   200] loss: 0.170
# [2,   300] loss: 0.153
# [2,   400] loss: 0.148
# Accuracy of the network on the 10000 test images: 96.77 %
# [3,   100] loss: 0.113
# [3,   200] loss: 0.120
# [3,   300] loss: 0.114
# [3,   400] loss: 0.116
# Accuracy of the network on the 10000 test images: 96.9 %
# [4,   100] loss: 0.089
# [4,   200] loss: 0.100
# [4,   300] loss: 0.091
# [4,   400] loss: 0.099
# Accuracy of the network on the 10000 test images: 97.31 %
# [5,   100] loss: 0.076
# [5,   200] loss: 0.086
# [5,   300] loss: 0.082
# [5,   400] loss: 0.082
# Accuracy of the network on the 10000 test images: 97.21 %
# [6,   100] loss: 0.070
# [6,   200] loss: 0.071
# [6,   300] loss: 0.074
# [6,   400] loss: 0.075
# Accuracy of the network on the 10000 test images: 97.54 %
# [7,   100] loss: 0.064
# [7,   200] loss: 0.065
# [7,   300] loss: 0.064
# [7,   400] loss: 0.071
# Accuracy of the network on the 10000 test images: 97.59 %
# [8,   100] loss: 0.053
# [8,   200] loss: 0.059
# [8,   300] loss: 0.057
# [8,   400] loss: 0.062
# Accuracy of the network on the 10000 test images: 97.89 %
# [9,   100] loss: 0.055
# [9,   200] loss: 0.049
# [9,   300] loss: 0.047
# [9,   400] loss: 0.061
# Accuracy of the network on the 10000 test images: 97.83 %
# [10,   100] loss: 0.044
# [10,   200] loss: 0.051
# [10,   300] loss: 0.047
# [10,   400] loss: 0.051
# Accuracy of the network on the 10000 test images: 97.75 %
# [11,   100] loss: 0.037
# [11,   200] loss: 0.051
# [11,   300] loss: 0.048
# [11,   400] loss: 0.046
# Accuracy of the network on the 10000 test images: 97.78 %
# [12,   100] loss: 0.041
# [12,   200] loss: 0.042
# [12,   300] loss: 0.038
# [12,   400] loss: 0.038
# Accuracy of the network on the 10000 test images: 97.82 %
# [13,   100] loss: 0.033
# [13,   200] loss: 0.037
# [13,   300] loss: 0.036
# [13,   400] loss: 0.046
# Accuracy of the network on the 10000 test images: 97.69 %
# [14,   100] loss: 0.030
# [14,   200] loss: 0.032
# [14,   300] loss: 0.033
# [14,   400] loss: 0.046
# Accuracy of the network on the 10000 test images: 97.76 %
# [15,   100] loss: 0.028
# [15,   200] loss: 0.028
# [15,   300] loss: 0.034
# [15,   400] loss: 0.031
# Accuracy of the network on the 10000 test images: 97.69 %
# [16,   100] loss: 0.030
# [16,   200] loss: 0.030
# [16,   300] loss: 0.035
# [16,   400] loss: 0.037
# Accuracy of the network on the 10000 test images: 97.76 %
# [17,   100] loss: 0.022
# [17,   200] loss: 0.026
# [17,   300] loss: 0.028
# [17,   400] loss: 0.032
# Accuracy of the network on the 10000 test images: 97.64 %
# [18,   100] loss: 0.022
# [18,   200] loss: 0.023
# [18,   300] loss: 0.026
# [18,   400] loss: 0.025
# Accuracy of the network on the 10000 test images: 97.74 %
# [19,   100] loss: 0.022
# [19,   200] loss: 0.024
# [19,   300] loss: 0.021
# [19,   400] loss: 0.032
# Accuracy of the network on the 10000 test images: 97.72 %
# [20,   100] loss: 0.020
# [20,   200] loss: 0.024
# [20,   300] loss: 0.024
# [20,   400] loss: 0.026
# Accuracy of the network on the 10000 test images: 97.78 %

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 7 * 7, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 64 * 7 * 7)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
class MnistTrainer_CNN(object):
    def __init__(self, batch_size):
        transform = transforms.Compose(
                [transforms.ToTensor()])
        self.trainset = torchvision.datasets.MNIST(
            root='./data',
            download=True,
            train=True,
            transform=transform)
        self.trainloader = torch.utils.data.DataLoader(
            self.trainset, batch_size=batch_size, shuffle=True, num_workers=2)

        self.testset = torchvision.datasets.MNIST(
            root='./data',
            train=False,
            download=True, transform=transform)
        self.testloader = torch.utils.data.DataLoader(
            self.testset, batch_size=1, shuffle=False, num_workers=2)

    def train(self, net, epochs=20, lr=0.05, momentum=0.9):
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.SGD(net.parameters(), lr=lr, momentum=momentum)

        for epoch in range(epochs):
            running_loss = 0.0
            net.train()

            for i, data in enumerate(self.trainloader):
                inputs, labels = data
                optimizer.zero_grad()

                outputs = net(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()

                running_loss += loss.item()
                if i % 100 == 99:
                    print('[%d, %5d] loss: %.3f' %
                          (epoch + 1, i + 1, running_loss / 100))
                    running_loss = 0.0

            net.eval()
            correct = 0
            total = 0
            with torch.no_grad():
                for data in self.testloader:
                    images, labels = data
                    outputs = net(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

            print('Accuracy of the network on the {} test images: {} %'.format(
                total, 100 * correct / total))

# %%
trainer = MnistTrainer_CNN(batch_size=64)
cnn = CNN()
epochs=10
trainer.train(cnn, epochs=epochs)
# Out:
# [1,   100] loss: 0.877
# [1,   200] loss: 0.173
# [1,   300] loss: 0.118
# [1,   400] loss: 0.089
# [1,   500] loss: 0.088
# [1,   600] loss: 0.078
# [1,   700] loss: 0.067
# [1,   800] loss: 0.068
# [1,   900] loss: 0.060
# Accuracy of the network on the 10000 test images: 98.11 %
# [2,   100] loss: 0.040
# [2,   200] loss: 0.048
# [2,   300] loss: 0.045
# [2,   400] loss: 0.041
# [2,   500] loss: 0.048
# [2,   600] loss: 0.053
# [2,   700] loss: 0.038
# [2,   800] loss: 0.046
# [2,   900] loss: 0.036
# Accuracy of the network on the 10000 test images: 98.66 %
# [3,   100] loss: 0.027
# [3,   200] loss: 0.030
# [3,   300] loss: 0.027
# [3,   400] loss: 0.028
# [3,   500] loss: 0.033
# [3,   600] loss: 0.034
# [3,   700] loss: 0.028
# [3,   800] loss: 0.035
# [3,   900] loss: 0.026
# Accuracy of the network on the 10000 test images: 98.92 %
# [4,   100] loss: 0.020
# [4,   200] loss: 0.017
# [4,   300] loss: 0.016
# [4,   400] loss: 0.026
# [4,   500] loss: 0.022
# [4,   600] loss: 0.020
# [4,   700] loss: 0.028
# [4,   800] loss: 0.027
# [4,   900] loss: 0.020
# Accuracy of the network on the 10000 test images: 99.07 %
# [5,   100] loss: 0.019
# [5,   200] loss: 0.017
# [5,   300] loss: 0.014
# [5,   400] loss: 0.012
# [5,   500] loss: 0.016
# [5,   600] loss: 0.017
# [5,   700] loss: 0.014
# [5,   800] loss: 0.016
# [5,   900] loss: 0.014
# Accuracy of the network on the 10000 test images: 99.06 %
# [6,   100] loss: 0.008
# [6,   200] loss: 0.008
# [6,   300] loss: 0.012
# [6,   400] loss: 0.010
# [6,   500] loss: 0.010
# [6,   600] loss: 0.013
# [6,   700] loss: 0.009
# [6,   800] loss: 0.017
# [6,   900] loss: 0.019
# Accuracy of the network on the 10000 test images: 99.21 %
# [7,   100] loss: 0.011
# [7,   200] loss: 0.007
# [7,   300] loss: 0.007
# [7,   400] loss: 0.017
# [7,   500] loss: 0.007
# [7,   600] loss: 0.010
# [7,   700] loss: 0.009
# [7,   800] loss: 0.010
# [7,   900] loss: 0.012
# Accuracy of the network on the 10000 test images: 99.23 %
# [8,   100] loss: 0.006
# [8,   200] loss: 0.007
# [8,   300] loss: 0.005
# [8,   400] loss: 0.008
# [8,   500] loss: 0.007
# [8,   600] loss: 0.009
# [8,   700] loss: 0.007
# [8,   800] loss: 0.009
# [8,   900] loss: 0.009
# Accuracy of the network on the 10000 test images: 99.1 %
# [9,   100] loss: 0.004
# [9,   200] loss: 0.009
# [9,   300] loss: 0.007
# [9,   400] loss: 0.009
# [9,   500] loss: 0.010
# [9,   600] loss: 0.004
# [9,   700] loss: 0.006
# [9,   800] loss: 0.008
# [9,   900] loss: 0.010
# Accuracy of the network on the 10000 test images: 98.99 %
# [10,   100] loss: 0.010
# [10,   200] loss: 0.009
# [10,   300] loss: 0.010
# [10,   400] loss: 0.005
# [10,   500] loss: 0.003
# [10,   600] loss: 0.006
# [10,   700] loss: 0.004
# [10,   800] loss: 0.005
# [10,   900] loss: 0.006
# Accuracy of the network on the 10000 test images: 98.81 %
